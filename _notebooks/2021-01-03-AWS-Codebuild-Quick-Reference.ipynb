# %% [markdown]
# # A quick guide to AWS Codebuild
# > Some important info and references
#
# - toc: true
# - badges: false
# - comments: false
# - categories: [codebuild, aws]

# %% [markdown]
# # Example of an AWS buildspec that builds Docker containers

# %% [markdown]
# ![image.png](attachment:6c20003e-9e2f-4913-8d7b-b2128cc6b590.png)
